# %%
import numpy as np
import matplotlib.pyplot as plt
wafers = np.load("Wafer_Map_Datasets.npz")

# %%
# np.set_printoptions(threshold=np.inf)
# print('arr_0 : ', wafers['arr_0'])
# print('arr_1 : ', wafers['arr_1'])
# wafers.files
arr_0 = wafers['arr_0']
# print(arr_0.shape)
arr_1 = wafers['arr_1']
# print(arr_1.shape)

# %%
# arr_1[33866]

# %%
np.set_printoptions(threshold=np.inf)
A = arr_0[33866]
B = arr_0[12000]
C = arr_0[24000]
D = arr_0[25000]
E = arr_0[26000]
F = arr_0[32000]
G = arr_0[33000]
H = arr_0[37015]
I = arr_0[35014]

# %%
plt.figure(figsize = (11,5.5),dpi = 250)
ax1 = plt.subplot(2, 5, 1)
ax1.matshow(A, cmap=plt.cm.Blues)
ax1.set_title("Normal")
# plt.show()

ax2 = plt.subplot(2, 5, 2)
ax2.matshow(B, cmap=plt.cm.Blues)
ax2.set_title("Center")

ax3 = plt.subplot(2, 5, 3)
ax3.matshow(C, cmap=plt.cm.Blues)
ax3.set_title("Donut")

ax4 = plt.subplot(2, 5, 4)
ax4.matshow(D, cmap=plt.cm.Blues)
ax4.set_title("Edge_Loc")

ax5 = plt.subplot(2, 5, 5)
ax5.matshow(E, cmap=plt.cm.Blues)
ax5.set_title("Edge_Ring")
# plt.show()

ax6 = plt.subplot(2, 5, 6)
ax6.matshow(F, cmap=plt.cm.Blues)
ax6.set_title("Loc")

ax7 = plt.subplot(2, 5, 7)
ax7.matshow(G, cmap=plt.cm.Blues)
ax7.set_title("Near_Full")

ax8 = plt.subplot(2, 5, 8)
ax8.matshow(H, cmap=plt.cm.Blues)
ax8.set_title("Scratch")

ax9 = plt.subplot(2, 5, 9)
ax9.matshow(I, cmap=plt.cm.Blues)
ax9.set_title("Random")
# plt.show()
plt.savefig("./single.png")

# %%
plt.figure(figsize = (11,16),dpi = 250)
title_Wafer =['','C+EL','C+ER','C+L','C+S','D+EL','D+ER','D+L','D+S','EL+L','EL+S','ER+L','ER+S','L+S','C+EL+L','C+EL+S','C+ER+L','C+ER+S','C+L+S','D+EL+L','D+EL+S','D+ER+L','D+ER+S','D+L+S','EL+L+S','ER+L+S','C+L+EL+S','C+L+ER+S','D+L+EL+S','D+L+ER+S']
# print(len(title_Wafer))
arr = [0,2000,4000,10000,11000,14000,16000,22000,23000,28000,35015,30000,36015,31000,6000,0,8000,3000,9000,18000,13000,20000,15000,21000,27000,29000,5000,7000,17000,19000]
for i in range(1,30):
    ax = plt.subplot(6,5,i)
    ax.matshow(arr_0[arr[i]],cmap=plt.cm.Blues)
    ax.set_title(title_Wafer[i])
# plt.show()
plt.savefig("./mixed.png")
